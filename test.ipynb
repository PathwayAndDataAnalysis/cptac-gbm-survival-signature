# %%
import pandas as pd

# %%
new_data = pd.read_csv("data/mmc3_expression.csv")
new_data
# Out:
#                   gene_id     gene_name                           gene_type  \
# 0       ENSG00000223972.5       DDX11L1  transcribed_unprocessed_pseudogene
# 1       ENSG00000238009.5  RP11-34P13.7                             lincRNA
# 2       ENSG00000230415.1  RP5-902P8.10                             lincRNA
# 3       ENSG00000213842.2       SUGT1P2                processed_pseudogene
# 4       ENSG00000227337.1    AC139452.2                processed_pseudogene
# ...                   ...           ...                                 ...
# 45909   ENSG00000144635.7      DYNC1LI1                      protein_coding
# 45910   ENSG00000231552.1       IGBP1P3                processed_pseudogene
# 45911   ENSG00000237676.1       RPL30P4                processed_pseudogene
# 45912  ENSG00000182973.17        CNOT10                      protein_coding
# 45913   ENSG00000251224.1    CNOT10-AS1                           antisense
#
# ...

# %%
# get the table headers
cols = new_data.columns
cols = cols[4:]
cols = list(cols)
cols
# Out:
# ['C3L-00104',
#  'C3L-00365',
#  'C3L-00674',
#  'C3L-00677',
#  'C3L-01040',
#  'C3L-01043',
#  'C3L-01045',
#  'C3L-01046',
#  'C3L-01048',
#  'C3L-01049',
#  'C3L-01061',
#  'C3L-01142',
#  'C3L-01146',
#  'C3L-01149',
#  'C3L-01154',
#  'C3L-01155',
#  'C3L-01156',
#  'C3L-01157',
#  'C3L-01327',
#  'C3L-01834',
#  'C3L-01887',
#  'C3L-02041',
#  'C3L-02465',
#  'C3L-02504',
#  'C3L-02542',
#  'C3L-02642',
#  'C3L-02704',
#  'C3L-02705',
#  'C3L-02707',
#  'C3L-02708',
#  'C3L-02900',
#  'C3L-02955',
#  'C3L-02970',
#  'C3L-02984',
#  'C3L-03260',
#  'C3L-03266',
#  'C3L-03387',
#  'C3L-03390',
#  'C3L-03392',
#  'C3L-03400',
#  'C3L-03405',
#  'C3L-03407',
#  'C3L-03681',
#  'C3L-03727',
#  'C3L-03728',
#  'C3L-03744',
#  'C3L-03748',
#  'C3L-03968',
#  'C3L-04084',
#  'C3N-00661',
#  'C3N-00662',
#  'C3N-00663',
#  'C3N-00665',
#  'C3N-01192',
#  'C3N-01196',
#  'C3N-01334',
#  'C3N-01364',
#  'C3N-01366',
#  'C3N-01367',
#  'C3N-01368',
#  'C3N-01369',
#  'C3N-01505',
# ...

# %%
surv_free = pd.read_csv("data/prog_free_surv.tsv", sep="\t")
ll = list(surv_free['Case'])
ll
# Out:
# ['C3N-03473',
#  'C3N-03088',
#  'C3L-02984',
#  'C3N-01364',
#  'C3N-03184',
#  'C3N-02784',
#  'C3L-03400',
#  'C3N-00663',
#  'C3N-02786',
#  'C3L-01142',
#  'C3L-02708',
#  'C3L-03390',
#  'C3N-01798',
#  'C3L-00674',
#  'C3L-01049',
#  'C3N-03182',
#  'C3N-02782',
#  'C3N-01851',
#  'C3L-01149',
#  'C3N-01814',
#  'C3L-01887',
#  'C3N-00661',
#  'C3N-01517',
#  'C3L-02465',
#  'C3L-03392',
#  'C3L-01046',
#  'C3L-02041',
#  'C3L-01154',
#  'C3L-02900',
#  'C3N-02181',
#  'C3N-03180',
#  'C3N-02186',
#  'C3N-02190',
#  'C3N-03183',
#  'C3N-01816',
#  'C3N-02769',
#  'C3N-03188',
#  'C3L-02704',
#  'C3N-03186',
#  'C3L-03407',
#  'C3L-01156',
#  'C3N-01369',
#  'C3L-00104',
#  'C3L-02707',
#  'C3L-02970',
#  'C3L-02542',
#  'C3L-01043',
#  'C3L-01146',
#  'C3L-03405',
#  'C3L-00365',
#  'C3N-02188',
#  'C3N-01852',
#  'C3N-01192',
#  'C3L-02705',
#  'C3L-01048',
#  'C3N-01818',
#  'C3L-03968',
#  'C3L-03266',
#  'C3N-02185',
#  'C3L-03747',
#  'C3L-03681',
#  'C3N-01366',
# ...

# %%
inter = []
for i in ll:
    if i in cols:
        inter.append(i)
print(len(inter))
# Out:
# 99
